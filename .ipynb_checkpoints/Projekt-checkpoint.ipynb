# %%
# -*- coding: utf-8 -*-
import numpy as np
import matplotlib.pyplot as plt
import time
import copy
import joblib
import scipy.integrate as integrate
from __future__ import unicode_literals
from sklearn import preprocessing as prep
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics imp ort classification_report
from sklearn.metrics import confusion_matrix
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.mixture import GaussianMixture as gm
from multiprocessing import Pool
from sklearn.cluster import KMeans

# %%
def normalizuj(tab):
    tabMean = np.mean(tab, axis = 0)
    tabStd = np.std(tab, axis = 0)
    tabStd[(tabStd == 0)] = 1
    return ((tab - tabMean) / tabStd)

def calkaBezDzielenia(a, b, gmm, eps):
    x = np.arange(a, b + eps, eps)
    y = np.exp(gmm.score_samples(x.reshape(-1, 1)))
    return np.sum(y[:n-1] + y[1:])


def calka(a, b, gmm, eps):
    n = (int) ((b - a) / eps)
    return calkaBezDzielenia(a, b, gmm, eps)*(b - a) / n / 2

def obieCalki(a, b, gmm, eps):
    n = (int) ((b - a) / eps)
    wynik = calkaBezDzielenia(a, b, gmm, eps)
    return wynik, wynik*(b-a)/n/2

# def gauss_function(x, amp, x0, sigma):
#     return amp * np.exp(-(x - x0) ** 2. / (2. * sigma ** 2.))

class LOB:
    def __init__(self, wiersz):
        self.zmiana = 0
        self.dzien = wiersz[0]
        self.czas = wiersz[1]
        i = 3
        while (wiersz[i] != 'ASK'):
            i += 1
        bid = wiersz[3:i]
        ask = wiersz[(i+1):]
        self.bid = np.zeros((int((len(bid) / 2)), 2))
        self.ask = np.zeros((int((len(ask) / 2)), 2))
        for i in range(0, len(bid), 2):
            self.bid[int(i / 2)][0] = float(bid[i]) 
            self.bid[int(i / 2)][1] = float(bid[i+1])
        for i in range(0, len(ask), 2):
            self.ask[int(i / 2)] = [float(ask[i]), float(ask[i+1])]
        self.midPrice = (self.bid[len(self.bid) - 1][0] + self.ask[0][0]) / 2
    def __str__(self):
        return "Dzień: " + self.dzien + ", Czas: " + self.czas + ", midPrice: " + str(self.midPrice)
    
# ustawianie wartości zmian i tworzenie dla nich osobnego wektora
def generujZmiane(X):
    for i in range(len(X) - 1):
        if (X[i].midPrice > X[i + 1].midPrice):
            X[i].zmiana = 1
        if (X[i].midPrice < X[i + 1].midPrice):
            X[i].zmiana = -1
        if (X[i].midPrice == X[i + 1].midPrice):
            X[i].zmiana = 0
    T = generujIndeksy(X)
    return np.array([i.zmiana for i in X])[T]

# interesują nas te loby, po którch nastąpiła zmiana mid price
def generujIndeksy(X):
    return np.arange(len(X))[np.array([(i.zmiana != 0) for i in X])]

# pierwszy sposób - imbalance to różnica najlepszego bid'a i ask'a przez ich sumę
def generujImbalance(X):
    i = 0
    Imbalance = np.zeros((X.shape[0], 1))
    for wiersz in X[T]:
        bid = wiersz.bid[-1, 1]
        ask = wiersz.ask[0, 1]
        Imbalance[i] = (bid - ask) / (bid + ask)
        i += 1
    return Imbalance

def testujDecisionFunction(xTest, yTest, najDecFun, clf):
    wynik = clf.decision_function(xTest).reshape(yTest.shape)
    yTestWiekszeOdZera = yTest > 0
    if (najDecFun[1]):
        return np.sum((wynik > najDecFun[0]) == yTestWiekszeOdZera) / yTest.shape[0]
    return np.sum((wynik < najDecFun[0]) == yTestWiekszeOdZera) / yTest.shape[0]

def najlepszeDecFun(yTrain, wynikDecFun):
    yTrainWiekszeOdZera = yTrain > 0
    tabWynikow = []
    for i in range(wynikDecFun.shape[0]):
        wy = np.sum((wynikDecFun < wynikDecFun[i]) == yTrainWiekszeOdZera) / yTrain.shape[0]
        tabWynikow.append(wy)
        wy = np.sum((wynikDecFun > wynikDecFun[i]) == yTrainWiekszeOdZera) / yTrain.shape[0]
        tabWynikow.append(wy)
    pozycjaMaxArg = np.argmax(tabWynikow)
    if (pozycjaMaxArg % 2 == 0):
        return (wynikDecFun[int(pozycjaMaxArg / 2)], 0)
    else:
        return (wynikDecFun[int(pozycjaMaxArg / 2)], 1)

def crossValidation(clf, data, dataClass, k):
    size = data.shape[0]
    arr = np.arange(size)
    np.random.shuffle(arr)
    err = 0
    n = int(size / k)
    for i in range(k):
        mask2 = arr[np.arange(i*n,min((i+1)*n,size))]
        mask1 = arr[np.concatenate((np.arange(i*n),np.arange((i+1)*n,size)))]
        X_train = data[mask1]
        y_train = dataClass[mask1]
        X_test = data[mask2]
        y_test = dataClass[mask2]  
        clf = clf.fit(X_train, y_train)
        if isinstance(clf, GridSearchCV):
            clf = clf.best_estimator_
        y_train = y_train.reshape((y_train.shape[0], 1))
        wynikDecFun = clf.decision_function(X_train).reshape(y_train.shape)
        najDecFun = najlepszeDecFun(y_train, wynikDecFun)        
        err += testujDecisionFunction(X_test, y_test, najDecFun, clf)
    return float(err) / k

def generujPrzedzialyRosnace(tablica, il, funkcja):
    wynik = np.zeros((len(tablica), 2 * il))
    for i in range(len(tablica)):
        a = 0
        b = 1
        for where in range(il):
            for j in range(a, b):
                wynik[i][where*2] += tablica[i][2*j]
                wynik[i][where*2 + 1] += tablica[i][2*j + 1]
            wynik[i][where*2] /= (b-a)
            wynik[i][where*2 + 1] /= (b-a)
            a = b
            b += where + 1
    return wynik

def wyliczCViWypisz(nazwa, tablica, mnoznik, liczbaKolumn, iloscIteracji):
    if mnoznik != 1:
        nazwa += '*' + str(mnoznik)
    wynik = crossValidation(svm, (((tablica[indeksy]).T[:liczbaKolumn]).T)*mnoznik, zmiana, iloscIteracji)
    print(nazwa, "zredukowana do ", liczbaKolumn, " kolumn, Cross-Vall score: ", wynik)

# %%
minimum = 100000
maksimum = 0
for wiersz in X:
    bid = wiersz.bid[0, 0]
    ask = wiersz.ask[-1, 0]
    if(ask > maksimum):
        maksimum = ask
    if(bid < minimum):
        minimum = bid 
liczbaWspolrzednych = int((maksimum - minimum) * 10 + 1)

param_grid = {'C': [1, 1e1, 1e2, 1e3, 1e4],
              'gamma': [0.0001, 0.001, 0.01, 0.1], 
             }
svm = GridSearchCV(SVC(kernel='rbf', class_weight='balanced'), param_grid, n_jobs = 6)

# %%
X = np.load("X.npy")
X1 = np.load("X1.npy")
X2 = np.load("X2.npy")
X3 = np.load("X3.npy")
X4 = np.load("X4.npy")
zmiana = np.load("zmiana.npy")
Imbalance1 = np.load("Imbalance1.npy")
indeksy = np.load("indeksy.npy")
tablica = np.load("tablica.npy")
gmmList = np.load("gmmList.npy")
tablicaCalekPo1 = np.load("tablCalekPo1.npy")
tablicaCalekPo1BezDzielenia = np.load("tabCalekPo1BezDz.npy")
tablicaTickowPo1 = np.load("tablicaTickowPo1.npy")
tablicaTickowRosnaca = np.load("tablicaTickowRosnaca.npy")
tablicaCalekRosnaca = np.load("tablicaCalekRosnaca.npy")
tablicaCalekRosnacaBezDzielenia = np.load("tablicaCalekRosnacaBezDzielenia.npy")
tabCalPo1razy170 = (((tablicaCalekPo1BezDzielenia[indeksy]).T[:170]).T)*1

# %%
nrWiersza = 430
midPrice = X[nrWiersza].midPrice

# %%
def narysujPrzykladowyWykres(xAsk, yAsk, xBid, yBid, midPrice, nawa, zblizone = False):
    plt.rc('font', family='Arial')
    plt.rcParams["figure.figsize"] = [8, 4]
    maks = np.max([np.max(yBid), np.max(yAsk)])
    plt.xlabel('Cena')
    plt.ylabel("Ilość")
    szerokosc = 0.2
    if (zblizone):
        plt.xticks(np.arange(midPrice - 10, midPrice + 12, 2))
        plt.axis([midPrice - 12, midPrice + 12, 0, maks])
        szerokosc /= 10
    else:
        plt.xticks([630, midPrice, 750, 800])
        plt.axis([625, 805, 0, maks])
    plt.title("Ilość akcji w stosunku do ceny")
    
    plt.bar(xBid, yBid, width=szerokosc, color = 'blue', edgecolor = "blue", label = "BID")
    plt.bar(xAsk, yAsk, width=szerokosc, color = 'red', edgecolor = "red", label = "ASK")
    
    plt.bar(midPrice, maks, width=szerokosc, color = 'green', edgecolor = "green", label = "mid-price")

    plt.legend()

    plt.tight_layout()
    plt.savefig(nawa)
    plt.show()

# %%
wiersz = X[nrWiersza]
narysujPrzykladowyWykres(wiersz.ask[:, 0], wiersz.ask[:, 1], wiersz.bid[:, 0], wiersz.bid[:, 1],
                         midPrice, "PrzykladDanychDlaListyLobow")

# %%
tablica = np.zeros((len(X), liczbaWspolrzednych), dtype=int)
i = 0
for wiersz in X:
    for item in wiersz.bid:
        tablica[i][int((item[0] - minimum)*10)] = int(-item[1])
    for item in wiersz.ask:
        tablica[i][int((item[0] - minimum)*10)] = int(item[1])
    i += 1

# %%
def generujPozycje(midPrice):
    pozMidPrice = (midPrice - minimum) * 10
    pozMidPriceInt = int(pozMidPrice)
    pozLewa = pozMidPriceInt
    pozPrawa = pozMidPriceInt + 1
    if (pozMidPrice == pozMidPriceInt):
        pozLewa -= 1
    return (pozLewa, pozPrawa)

def generujPrzedzialy(midPrice, ilosc, f):
    pozLewa, pozPrawa = generujPozycje(midPrice)
    przedzialy = []
    wspXowe = []
    for i in range(ilosc):
        fi = f(i)
        wspXowe.append((pozPrawa / 10) + minimum + (fi / 2))
        wspXowe.append((pozLewa / 10) + minimum - (fi / 2))
        fi10 = int(fi*10)
        tmpList = np.arange(fi10)
        przedzialy.append(pozPrawa + tmpList)
        pozPrawa += fi10
        pozLewa -= fi10
        przedzialy.append(pozLewa + 1 + tmpList)
    return przedzialy, wspXowe
        
def generujTabliceTickow(ilosc, f):
    wynik = np.zeros((len(X), 2 * ilosc))
    listaWspXowych = []
    for i in range(len(X)):
        wiersz = tablica[i]
        przedzialy, wspXowe = generujPrzedzialy(X[i].midPrice, ilosc, f)
        listaWspXowych.append(wspXowe)
        for j in range(2 * ilosc):
            przedzial = przedzialy[j]
            przedzial = przedzial[przedzial >= 0]
            przedzial = przedzial[przedzial < liczbaWspolrzednych]
            wynik[i][j] = np.sum(wiersz[przedzial])
    return wynik, listaWspXowych

# %%
tablicaTickowPo1, tablicaTickowPo1Wsp = generujTabliceTickow(130, lambda x: 1)

# %%
np.save("tablicaTickowPo1.npy", tablicaTickowPo1)
np.save("tablicaTickowPo1Wsp.npy", tablicaTickowPo1Wsp)

# %%
wiersz = tablicaTickowPo1[nrWiersza]
wierszWsp = np.array(tablicaTickowPo1Wsp[nrWiersza])
askMask = np.arange(0, len(wiersz), 2)
bidMask = askMask + 1
narysujPrzykladowyWykres(wierszWsp[askMask], wiersz[askMask],
                         wierszWsp[bidMask], wiersz[bidMask] * (-1),
                         midPrice, "PrzykladDanychDlaTablicyTickowPo1")

narysujPrzykladowyWykres(wierszWsp[askMask], wiersz[askMask],
                         wierszWsp[bidMask], wiersz[bidMask] * (-1),
                         midPrice, "PrzykladDanychDlaTablicyTickowPo1Przyblizenie", True)

# %%
def funkcjaPrzedzialow(i):
    return (int((0.1 + (0.05 + i / 20) * np.sqrt(i)) * 10) / 10)

# %%
plt.rcParams["figure.figsize"] = [7, 3]
dl = 30
plt.plot(np.arange(dl), [funkcjaPrzedzialow(i) for i in range(dl)], color = "red", label = "funkcjaPrzedzialow(x)")
plt.plot(np.arange(dl), [1 for i in range(dl)], color = "blue", label = "lambda x: 1")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Wykres funkcji funkcjaPrzedzialow")

plt.legend()

plt.tight_layout()
plt.savefig("PrzykladFunkcjiPrzedzialow")
plt.show()

# %%
tablicaTickowRosnaca, tablicaTickowRosnacaWsp = generujTabliceTickow(40, funkcjaPrzedzialow)

# %%
np.save("tablicaTickowRosnaca.npy", tablicaTickowRosnaca)
np.save("tablicaTickowRosnacaWsp.npy", tablicaTickowRosnacaWsp)

# %%
wiersz = tablicaTickowRosnaca[nrWiersza]
wierszWsp = np.array(tablicaTickowRosnacaWsp[nrWiersza])
askMask = np.arange(0, len(wiersz), 2)
bidMask = askMask + 1
narysujPrzykladowyWykres(wierszWsp[askMask], wiersz[askMask],
                         wierszWsp[bidMask], wiersz[bidMask] * (-1),
                         midPrice, "PrzykladDanychDlaTablicyTickowRosnacej")

narysujPrzykladowyWykres(wierszWsp[askMask], wiersz[askMask],
                         wierszWsp[bidMask], wiersz[bidMask] * (-1),
                         midPrice, "PrzykladDanychDlaTablicyTickowRosnacejPrzyblizenie", True)

# %%
forMM = []
for i in range(X.size):
    oneLine = []
    for ask in X[i].ask:
        oneLine.extend([ask[0] for j in range(int(ask[1]/100))])
    for bid in X[i].bid:
        oneLine.extend([bid[0] for j in range(int(bid[1]/100))])
    forMM.append(oneLine)

# %%
gmmList = []
gmm = gm(n_components=30, n_init=10, covariance_type="full", warm_start = True, tol = 0.001)
for oneLine in forMM:
    gmm.fit(X=np.expand_dims(oneLine, 1))
    gmmList.append(copy.deepcopy(gmm))

# %%
def calkaBezDzielenia(a, b, gmm, eps):
    x = np.arange(a, b + 0.0000001, eps)
    y = np.exp(gmm.score_samples(x.reshape(-1, 1)))
    return np.sum(y[:x.shape[0] - 1] + y[1:])*eps

def calka(a, b, gmm, eps):
    n = (int) ((b - a) / eps)
    return (calkaBezDzielenia(a, b, gmm, eps) / 2)

def obieCalki(a, b, gmm, eps):
    n = (int) ((b - a) / eps)
    wynik = calkaBezDzielenia(a, b, gmm, eps)*(b - a)
    return wynik, wynik/n/2

def calkaBezDzieleniaF(a, b, f, eps):
    x = np.arange(a, b + 0.0000001, eps)
    y = f(x.reshape(-1, 1))
    return np.sum(y[:x.shape[0] - 1] + y[1:])*eps

def calkaF(a, b, gmm, eps):
    n = (int) ((b - a) / eps)
    return (calkaBezDzieleniaF(a, b, gmm, eps) / 2)

# %%
def generujTabliceTickowDlaGMM(ilosc, f):
    wynik = np.zeros((len(X), 2 * ilosc))
    listaWspXowych = []
    for i in range(len(X)):
        wiersz = tablica[i]
        pozLewa = X[i].midPrice
        pozPrawa = pozLewa
        
        for j in range(ilosc):
            fj = f(j)
            wynik[i][2*j] = calka(pozPrawa, pozPrawa + fj, gmmList[i], 0.001)
            wynik[i][2*j + 1] = calka(pozLewa - fj, pozLewa, gmmList[i], 0.001)
            pozPrawa += fj
            pozLewa -= fj
            
    return wynik

# %%
tablicaCalekPo1 = np.zeros((X.size, 400))
tablicaCalekPo1BezDzielenia = np.zeros((X.size, 400))
# parzyste to na prawdo od mid
przedzial = 1
for k in range(X.size):
    mid = X[k].midPrice
    for i in range(400):
        a = 0
        b = 0
        if (i%2 == 0):
            a = mid + int(i/2)
            b = a + przedzial
        else:
            b = mid - int(i/2)
            a = b - przedzial
        tablicaCalekPo1BezDzielenia[k][i], tablicaCalekPo1[k][i] = obieCalki(a, b, gmmList[k], 0.001)

# %%
tablicaCalekPo1 = generujTabliceTickowDlaGMM(130, lambda x: 1)

# %%
np.save("tablicaCalekPo1.npy", tablicaCalekPo1)

# %%
tablicaCalekRosnaca = generujTabliceTickowDlaGMM(34, funkcjaPrzedzialow)

# %%
np.save("tablicaCalekRosnaca.npy", tablicaCalekRosnaca)

# %%
# pierwszy sposób - imbalance to różnica najlepszego bid'a i ask'a przez ich sumę
def generujImbalance(X):
    i = 0
    Imbalance = np.zeros((X.shape[0], 1))
    for wiersz in X: 
        bid = wiersz.bid[-1, 1]
        ask = wiersz.ask[0, 1]
        Imbalance[i] = (bid - ask) / (bid + ask)
        i += 1
    return Imbalance

def generujWektor(k):
    dlugosc = imbalance.shape[0]
    ImbalanceWektor = np.zeros((dlugosc, k))
    for i in range(k, dlugosc):
        ImbalanceWektor[i] = imbalance[(i-k) : i].reshape(k)
    return ImbalanceWektor

# %%
imbalance = generujImbalance(X)

# %%
np.save("imbalance.npy", imbalance)

# %%
imbalance3 = generujWektor(3)

# %%
def testujDecisionFunction(xTest, yTest, najDecFun, clf):
    wynik = clf.decision_function(xTest).reshape(yTest.shape)
    yTestWiekszeOdZera = yTest > 0
    if (najDecFun[1]):
        return np.sum((wynik > najDecFun[0]) == yTestWiekszeOdZera) / yTest.shape[0]
    return np.sum((wynik < najDecFun[0]) == yTestWiekszeOdZera) / yTest.shape[0]

def najlepszeDecFun(yTrain, wynikDecFun):
    yTrainWiekszeOdZera = yTrain > 0
    tabWynikow = []
    for i in range(wynikDecFun.shape[0]):
        wy = np.sum((wynikDecFun < wynikDecFun[i]) == yTrainWiekszeOdZera) / yTrain.shape[0]
        tabWynikow.append(wy)
        wy = np.sum((wynikDecFun > wynikDecFun[i]) == yTrainWiekszeOdZera) / yTrain.shape[0]
        tabWynikow.append(wy)
    pozycjaMaxArg = np.argmax(tabWynikow)
    if (pozycjaMaxArg % 2 == 0):
        return (wynikDecFun[int(pozycjaMaxArg / 2)], 0)
    else:
        return (wynikDecFun[int(pozycjaMaxArg / 2)], 1)

def crossValidation(clf, data, dataClass, k):
    size = data.shape[0]
    arr = np.arange(size)
    np.random.shuffle(arr)
    err = 0
    n = int(size / k)
    for i in range(k):
        mask2 = arr[np.arange(i*n,min((i+1)*n,size))]
        mask1 = arr[np.concatenate((np.arange(i*n),np.arange((i+1)*n,size)))]
        X_train = data[mask1]
        y_train = dataClass[mask1]
        X_test = data[mask2]
        y_test = dataClass[mask2]  
        clf = clf.fit(X_train, y_train)
        clfBest = clf.best_estimator_
        print("C=",clfBest.C,", coef0=", clfBest.coef0, ", degree=", clfBest.degree, ", gamma=", clfBest.gamma, 
              ", kernel=", clfBest.kernel, ", shrinking=", clfBest.shrinking, "tol=", clfBest.tol)
        y_train = y_train.reshape((y_train.shape[0], 1))
        wynikDecFun = clfBest.decision_function(X_train).reshape(y_train.shape)
        najDecFun = najlepszeDecFun(y_train, wynikDecFun)        
        err += testujDecisionFunction(X_test, y_test, najDecFun, clfBest)
    return float(err) / k

def crossValidationPoKolei(clf, data, dataClass, k, p):
    size = data.shape[0]
    arr = np.arange(size)
    err = 0
    n = int(size / (k+1))
    trainCount = int(2 * n * p)
    for i in range(k):
        trainMask = np.arange(i*n, i*n + trainCount)
        testMask = np.arange(i*n + trainCount, (i+2)*n)
        X_train = data[trainMask]
        y_train = dataClass[trainMask]
        X_test = data[testMask]
        y_test = dataClass[testMask]  
        clf = clf.fit(X_train, y_train)
        clfBest = clf.best_estimator_
        print("C=",clfBest.C,", coef0=", clfBest.coef0, ", degree=", clfBest.degree, ", gamma=", clfBest.gamma, 
              ", kernel=", clfBest.kernel, ", shrinking=", clfBest.shrinking, "tol=", clfBest.tol)
        y_train = y_train.reshape((y_train.shape[0], 1))
        wynikDecFun = clfBest.decision_function(X_train).reshape(y_train.shape)
        najDecFun = najlepszeDecFun(y_train, wynikDecFun)        
        wynik = testujDecisionFunction(X_test, y_test, najDecFun, clfBest)
        print(wynik)
        err += wynik
    return float(err) / k

def wyliczCVPoKoleiiWypisz(nazwa, tablica, iloscIteracji, p, liczbaKolumn, svm):
    wynik = crossValidationPoKolei(svm, (((tablica[indeksy]).T[:liczbaKolumn]).T), zmiana, iloscIteracji, p)
    print(nazwa, "zredukowana do ", liczbaKolumn, " kolumn, Cross-Vall score: ", wynik)
    print()

# %%
param_grid = {'C': [1e-5, 1e-2, 1, 1e2, 1e5],
              'gamma': [1e-5, 1e-2, 1, 1e2, 1e5],
             'kernel': ['rbf', 'linear']}
svm = GridSearchCV(SVC(class_weight='balanced', cache_size = 2000), param_grid, n_jobs = 6)

# %%
wyliczCVLosoweiWypisz("tablicaCalekPo1", tablicaCalekPo1, 5, tablicaCalekPo1.shape[1], svm)
# Out:
# tablicaCalekPo1 zredukowana do  260  kolumn, Cross-Vall score:  0.5124731182795699

# %%
wyliczCVLosoweiWypisz("tablicaCalekPo1", tablicaCalekPo1*1000, 2, 100, svm)
# Out:
# C= 1 , coef0= 0.0 , degree= 3 , gamma= 0.1 , kernel= rbf , shrinking= True tol= 0.001
# C= 1 , coef0= 0.0 , degree= 3 , gamma= 0.1 , kernel= rbf , shrinking= True tol= 0.001
# tablicaCalekPo1 zredukowana do  100  kolumn, Cross-Vall score:  0.516122098022356
# C= 1 , coef0= 0.0 , degree= 3 , gamma= 0.1 , kernel= rbf , shrinking= True tol= 0.001

# %%
wyliczCVLosoweiWypisz("tablicaCalekPo1", tablicaCalekPo1, 5, 100, svm)
# Out:
# tablicaCalekPo1 zredukowana do  100  kolumn, Cross-Vall score:  0.49978494623655917

# %%
wyliczCVPoKoleiiWypisz("tablicaCalekPo1", prep.Normalizer().fit_transform(prep.StandardScaler().fit_transform(tablicaCalekPo1)), 4, 0.8, 100, svm)
# Out:
# C= 1 , coef0= 0.0 , degree= 3 , gamma= 100000.0 , kernel= rbf , shrinking= True tol= 0.001
# C= 100.0 , coef0= 0.0 , degree= 3 , gamma= 0.01 , kernel= rbf , shrinking= True tol= 0.001
# C= 1 , coef0= 0.0 , degree= 3 , gamma= 100000.0 , kernel= rbf , shrinking= True tol= 0.001
# C= 100.0 , coef0= 0.0 , degree= 3 , gamma= 0.01 , kernel= rbf , shrinking= True tol= 0.001
# tablicaCalekPo1 zredukowana do  100  kolumn, Cross-Vall score:  0.5029121863799283

# %%
wyliczCVPoKoleiiWypisz("tablicaCalekPo1", imbalance, 4, 0.75, 100, svm)
# Out:
# C= 1 , coef0= 0.0 , degree= 3 , gamma= 0.01 , kernel= rbf , shrinking= True tol= 0.001
# 0.563440860215
# C= 100.0 , coef0= 0.0 , degree= 3 , gamma= 1 , kernel= rbf , shrinking= True tol= 0.001
# 0.501075268817
# C= 100.0 , coef0= 0.0 , degree= 3 , gamma= 1 , kernel= rbf , shrinking= True tol= 0.001
# 0.52688172043
# C= 100.0 , coef0= 0.0 , degree= 3 , gamma= 1 , kernel= rbf , shrinking= True tol= 0.001
# 0.548387096774
# tablicaCalekPo1 zredukowana do  100  kolumn, Cross-Vall score:  0.5349462365591398

# %%
def wielkiTest(nazwa, tablica, ilosc = 4, procent = 0.75, iloscKolumn = 120):
    wyliczCVPoKoleiiWypisz(nazwa, tablica, ilosc, procent, iloscKolumn, svm)
    wyliczCVPoKoleiiWypisz(nazwa + ' (stand -> normal)',  prep.Normalizer().fit_transform(prep.StandardScaler().fit_transform(tablica)), ilosc, procent, iloscKolumn, svm)
    wyliczCVPoKoleiiWypisz(nazwa + ' (norm -> stand)', prep.StandardScaler().fit_transform(prep.Normalizer().fit_transform(tablica)), ilosc, procent, iloscKolumn, svm)

# %%
print(3)
# Out:
# 3

# %%
wielkiTest('Imbalance', imbalance)
# Out:
# C= 1 , coef0= 0.0 , degree= 3 , gamma= 0.01 , kernel= rbf , shrinking= True tol= 0.001
# 0.563440860215
# C= 100.0 , coef0= 0.0 , degree= 3 , gamma= 1 , kernel= rbf , shrinking= True tol= 0.001
# 0.501075268817
# C= 100.0 , coef0= 0.0 , degree= 3 , gamma= 1 , kernel= rbf , shrinking= True tol= 0.001
# 0.52688172043
# C= 100.0 , coef0= 0.0 , degree= 3 , gamma= 1 , kernel= rbf , shrinking= True tol= 0.001
# 0.548387096774
# Imbalance zredukowana do  120  kolumn, Cross-Vall score:  0.5349462365591398
#
# C= 0.01 , coef0= 0.0 , degree= 3 , gamma= 1e-05 , kernel= linear , shrinking= True tol= 0.001
# 0.550537634409
# C= 0.01 , coef0= 0.0 , degree= 3 , gamma= 1e-05 , kernel= linear , shrinking= True tol= 0.001
# 0.501075268817
# C= 0.01 , coef0= 0.0 , degree= 3 , gamma= 1e-05 , kernel= linear , shrinking= True tol= 0.001
# 0.529032258065
# C= 0.01 , coef0= 0.0 , degree= 3 , gamma= 1e-05 , kernel= linear , shrinking= True tol= 0.001
# 0.544086021505
# ...

# %%
wielkiTest('tablicaCalekPo1', tablicaCalekPo1)
# Out:
# C= 100000.0 , coef0= 0.0 , degree= 3 , gamma= 0.01 , kernel= rbf , shrinking= True tol= 0.001
# 0.496774193548
# C= 100000.0 , coef0= 0.0 , degree= 3 , gamma= 1e-05 , kernel= linear , shrinking= True tol= 0.001
# 0.49247311828
# C= 1 , coef0= 0.0 , degree= 3 , gamma= 1e-05 , kernel= rbf , shrinking= True tol= 0.001
# 0.481720430108
# C= 1 , coef0= 0.0 , degree= 3 , gamma= 1e-05 , kernel= rbf , shrinking= True tol= 0.001
# 0.494623655914
# tablicaCalekPo1 zredukowana do  120  kolumn, Cross-Vall score:  0.4913978494623656
#
# C= 100.0 , coef0= 0.0 , degree= 3 , gamma= 1e-05 , kernel= linear , shrinking= True tol= 0.001
# 0.47311827957
# C= 1 , coef0= 0.0 , degree= 3 , gamma= 100.0 , kernel= rbf , shrinking= True tol= 0.001
# 0.494623655914
# C= 1 , coef0= 0.0 , degree= 3 , gamma= 1e-05 , kernel= rbf , shrinking= True tol= 0.001
# 0.490322580645
# C= 1 , coef0= 0.0 , degree= 3 , gamma= 1e-05 , kernel= rbf , shrinking= True tol= 0.001
# 0.501075268817
# ...

# %%
wielkiTest('tablicaCalekRosnaca', tablicaCalekRosnaca)
# Out:
# C= 100.0 , coef0= 0.0 , degree= 3 , gamma= 1e-05 , kernel= linear , shrinking= True tol= 0.001
# 0.483870967742
# C= 100000.0 , coef0= 0.0 , degree= 3 , gamma= 1e-05 , kernel= linear , shrinking= True tol= 0.001
# 0.501075268817
# C= 1 , coef0= 0.0 , degree= 3 , gamma= 1e-05 , kernel= rbf , shrinking= True tol= 0.001
# 0.475268817204
# C= 1 , coef0= 0.0 , degree= 3 , gamma= 1e-05 , kernel= rbf , shrinking= True tol= 0.001
# 0.524731182796
# tablicaCalekRosnaca zredukowana do  120  kolumn, Cross-Vall score:  0.4962365591397849
#
# C= 100.0 , coef0= 0.0 , degree= 3 , gamma= 0.01 , kernel= rbf , shrinking= True tol= 0.001
# 0.479569892473
# C= 100000.0 , coef0= 0.0 , degree= 3 , gamma= 0.01 , kernel= rbf , shrinking= True tol= 0.001
# 0.531182795699
# C= 1 , coef0= 0.0 , degree= 3 , gamma= 1e-05 , kernel= rbf , shrinking= True tol= 0.001
# 0.50752688172
# C= 100.0 , coef0= 0.0 , degree= 3 , gamma= 100000.0 , kernel= rbf , shrinking= True tol= 0.001
# 0.47311827957
# ...

# %%
wielkiTest('tablicaTickowPo1', tablicaTickowPo1)

# %%
wielkiTest('tablicaTickowRosnaca', tablicaTickowRosnaca)

# %%
wielkiTest('Imbalance(3)', imbalance3)

# %%
ile = 1
wielkiTest('Imbalance', imbalance, ilosc = ile)
wielkiTest('Imbalance(13)', generujWektor(13), ilosc = ile)
wielkiTest('tablicaCalekPo1', tablicaCalekPo1, ilosc = ile)
wielkiTest('tablicaCalekRosnaca', tablicaCalekRosnaca,ilosc = ile)
wielkiTest('tablicaTickowPo1', tablicaTickowPo1, ilosc = ile)
wielkiTest('tablicaTickowRosnaca', tablicaTickowRosnaca, ilosc = ile)

# %%
nana = prep.Normalizer().fit_transform(tablicaCalekPo1Znormalizowana)

# %%
tablicaCalekPo1Znormalizowana = copy.deepcopy(tablicaCalekPo1)

# %%
len(TablicaTickowPo1Wsp[nrWiersza])
# Out:
# 300

# %%
imbalance = np.zeros((X.shape[0], 1))
imbalance[indeksy, 0] = zmiana

# %%
slownik = {}
slownik['tablica'] = tablica
slownik['tablicaCalekPo1'] = tablicaCalekPo1
slownik['tablicaCalekPo1BezDzielenia'] = tablicaCalekPo1BezDzielenia
slownik['tablicaTickowPo1'] = tablicaTickowPo1
slownik['tablicaTickowRosnaca'] = tablicaTickowRosnaca
slownik['tablicaCalekRosnacaBezDzielenia'] = tablicaCalekRosnacaBezDzielenia 
slownik['tabCalPo1razy170'] = tabCalPo1razy170

# %%
minimum = 100000
maksimum = 0
for wiersz in X:
    bid = wiersz.bid[0, 0]
    ask = wiersz.ask[-1, 0]
    if(ask > maksimum):
        maksimum = ask
    if(bid < minimum):
        minimum = bid 
liczbaWspolrzednych = int((maksimum - minimum) * 10 + 1)

param_grid = {'C': [1, 1e1, 1e2, 1e3, 1e4],
              'gamma': [0.0001, 0.001, 0.01, 0.1], 
             }
svm = GridSearchCV(SVC(kernel='rbf', class_weight='balanced'), param_grid, n_jobs = 6)

# %%
daneS = 'OrderBookSnapshots.csv';
with open(daneS, 'r') as f:
    dane = f.readlines()

# %%
X = []
X1 = []
X2 = []
X3 = []
X4 = []
for wiersz in dane:
    newWiersz = wiersz.split()
    X.append(LOB(newWiersz))
    X1.append(LOB(newWiersz))
    X2.append(LOB(newWiersz))
    X3.append(LOB(newWiersz))
    X4.append(LOB(newWiersz))
X = np.array(X)
X1 = np.array(X1)
X2 = np.array(X2)
X3 = np.array(X3)
X4 = np.array(X4)

# %%
np.save("X.npy", X)
np.save("X1.npy", X1)
np.save("X2.npy", X2)
np.save("X3.npy", X3)
np.save("X4.npy", X4)

# %%
plt.bar(X[0].bid[:, 0], X[0].bid[:, 1], color = 'red')
plt.plot(X[0].bid[:, 0], X[0].bid[:, 1], 'ro')
plt.bar(X[0].ask[:, 0], X[0].ask[:, 1], color = 'green')
plt.plot(X[0].ask[:, 0], X[0].ask[:, 1], 'go')
plt.plot(X[0].midPrice, 1000, "bo")
plt.show()

# %%
zmiana = generujZmiane(X)
Imbalance1 = generujImbalance1(X)

# %%
np.save("zmiana.npy", zmiana)
np.save("Imbalance1.npy", Imbalance1)

# %%
indeksy = generujIndeksy(X)

# %%
np.save("indeksy.npy", indeksy)

# %%
changesPercentage = (zmiana.size / X.size)
print(changesPercentage)
# Out:
# 0.8498355864084765

# %%
tablica = np.zeros((len(X), liczbaWspolrzednych), dtype=int)
i = 0
for wiersz in X:
    for item in wiersz.bid:
        tablica[i][int((item[0] - minimum)*10)] = int(-item[1])
    for item in wiersz.ask:
        tablica[i][int((item[0] - minimum)*10)] = int(item[1])
    i += 1

# %%
np.save("tablica.npy", tablica)

# %%
tablica = np.load("tablica.npy")

# %%
forMM = []
for i in range(X.size):
    oneLine = []
    for ask in X[i].ask:
        oneLine.extend([ask[0] for j in range(int(ask[1]/100))])
    for bid in X[i].bid:
        oneLine.extend([bid[0] for j in range(int(bid[1]/100))])
    forMM.append(oneLine)

# %%
# np.save("forMM.npy", forMM)

# %%
gmmList = []
gmm = gm(n_components=30, n_init=10, covariance_type="full", warm_start = True, tol = 0.001)
for oneLine in forMM:
    gmm.fit(X=np.expand_dims(oneLine, 1))
    gmmList.append(copy.deepcopy(gmm))

# %%
np.save("gmmList.npy", gmmList)

# %%
tablicaCalekPo1 = np.zeros((X.size, 400))
tablicaCalekPo1BezDzielenia = np.zeros((X.size, 400))
# parzyste to na prawdo od mid
przedzial = 1
for k in range(X.size):
    mid = X[k].midPrice
    for i in range(400):
        a = 0
        b = 0
        if (i%2 == 0):
            a = mid + int(i/2)
            b = a + przedzial
        else:
            b = mid - int(i/2)
            a = b - przedzial
        tablicaCalekPo1BezDzielenia[k][i], tablicaCalekPo1[k][i] = obieCalki(a, b, gmmList[k], 0.001)

# %%
np.save("tablCalekPo1.npy", tablicaCalekPo1)
np.save("tabCalekPo1BezDz.npy", tablicaCalekPo1BezDzielenia)

# %%
tablicaTickowPo1 = generujPrzedzialy(X, tablica, 10, 200)

# %%
np.save("tablicaTickowPo1.npy", tablicaTickowPo1)

# %%
il = 20
tablicaTickowRosnaca = generujPrzedzialyRosnace(tablicaTickowPo1, il)
tablicaCalekRosnaca = generujPrzedzialyRosnace(tablicaCalekPo1, il)

# %%
np.save("tablicaTickowRosnaca.npy", tablicaTickowRosnaca)
np.save("tablicaCalekRosnaca", tablicaCalekRosnaca)

# %%
il = 20
tablicaCalekRosnacaBezDzielenia = generujPrzedzialyRosnace(tablicaCalekPo1BezDzielenia, il)

# %%
np.save("tablicaCalekRosnacaBezDzielenia.npy", tablicaCalekRosnacaBezDzielenia)

# %%
x = forMM[5]

gmm = gm(n_components=30, n_init=10, covariance_type="full", warm_start = True, tol = 0.001)
gmm.fit(X=np.expand_dims(x, 1))

minimalne = X[5].bid[0][0]-5
maksymalne = X[5].ask[-1][0]+5
gmm_x = np.linspace(minimalne, maksymalne, 10000)
gmm_y = np.exp(gmm.score_samples(gmm_x.reshape(-1, 1)))
plt.ylim(0,0.1)
plt.plot(gmm_x, gmm_y)
plt.savefig("przykladowyWykresGausowski1")
plt.show()

# %%
plt.bar([i*0.1 + minimum for i in range(tablica.shape[1])], np.abs(tablica[5]) / 1000000)
plt.xlim(X[5].bid[0][0]-5, X[5].ask[-1][0]+5)
plt.ylim(0,0.1)
plt.savefig("przykladowyWykresHistogram1")
plt.show()

# %%
plt.ylim(0,0.01)
plt.plot(gmm_x, gmm_y)
plt.savefig("przykladowyWykresGausowski01")
plt.show()

# %%
print("Cross-Vall score:", crossValidation(svm, tablica[indeksy], zmiana, 2))
# Out:
# Cross-Vall score: 0.5010748065348237

# %%
print("tablicaCalekPo1, Cross-Vall score:", crossValidation(svm, tablicaCalekPo1[indeksy], zmiana, 5))
# Out:
# tablicaCalekPo1, Cross-Vall score: 0.5034408602150537

# %%
print("tablicaCalekRosnaca, Cross-Vall score:", crossValidation(svm, tablicaCalekRosnaca[indeksy], zmiana, 5))
# Out:
# tablicaCalekRosnaca, Cross-Vall score: 0.489247311827957

# %%
print("tablicaTickowPo1, Cross-Vall score:", crossValidation(svm, tablicaTickowPo1[indeksy], zmiana, 5))
# Out:
# tablicaTickowPo1, Cross-Vall score: 0.5010752688172043

# %%
print("tablicaTickowRosnaca, Cross-Vall score:", crossValidation(svm, tablicaTickowRosnaca[indeksy], zmiana, 5))
# Out:
# tablicaTickowRosnaca, Cross-Vall score: 0.5010752688172043

# %%
print("tablicaCalekPo1*100000, Cross-Vall score:", crossValidation(svm, tablicaCalekPo1[indeksy]*100000, zmiana, 5))
# Out:
# tablicaCalekPo1, Cross-Vall score: 0.5135483870967741

# %%
print("tablicaCalekRosnaca*100000, Cross-Vall score:", crossValidation(svm, tablicaCalekRosnaca[indeksy]*100000, zmiana, 5))
# Out:
# tablicaCalekRosnaca, Cross-Vall score: 0.5021505376344086

# %%
print("tablicaCalekPo1*10000000, Cross-Vall score:", crossValidation(svm, tablicaCalekPo1[indeksy]*10000000, zmiana, 5))
# Out:
# tablicaCalekPo1*10000000, Cross-Vall score: 0.5012903225806452

# %%
print("tablicaCalekPo1*100, Cross-Vall score:", crossValidation(svm, tablicaCalekPo1[indeksy]*100, zmiana, 5))
# Out:
# tablicaCalekPo1*100000, Cross-Vall score: 0.518494623655914

# %%
print("tablicaCalekPo1*1000, Cross-Vall score:", crossValidation(svm, tablicaCalekPo1[indeksy]*1000, zmiana, 5))
# Out:
# tablicaCalekPo1*1000, Cross-Vall score: 0.5232258064516129

# %%
print("tablicaCalekPo1*1000, Cross-Vall score:", crossValidation(svm, (((tablicaCalekPo1[indeksy]).T[:200]).T)*1000, zmiana, 5))
# Out:
# tablicaCalekPo1*1000, Cross-Vall score: 0.5165591397849463

# %%
print("tablicaCalekPo1*1000, Cross-Vall score:", crossValidation(svm, (((tablicaCalekPo1[indeksy]).T[:100]).T)*1000, zmiana, 5))
# Out:
# tablicaCalekPo1*1000, Cross-Vall score: 0.5350537634408602

# %%
for i in (np.arange(10, 110, 10)):
    print("tablicaCalekPo1*1000, zredukowana do ", i, " kolumn, Cross-Vall score:", crossValidation(svm, (((tablicaCalekPo1[indeksy]).T[:i]).T)*1000, zmiana, 5))
# Out:
# tablicaCalekPo1*1000, zredukowana do  10  kolumn, Cross-Vall score: 0.5055913978494624
# tablicaCalekPo1*1000, zredukowana do  20  kolumn, Cross-Vall score: 0.5075268817204301
# tablicaCalekPo1*1000, zredukowana do  30  kolumn, Cross-Vall score: 0.5281720430107527
# tablicaCalekPo1*1000, zredukowana do  40  kolumn, Cross-Vall score: 0.5313978494623657
# tablicaCalekPo1*1000, zredukowana do  50  kolumn, Cross-Vall score: 0.5270967741935484
# tablicaCalekPo1*1000, zredukowana do  60  kolumn, Cross-Vall score: 0.5105376344086021
# tablicaCalekPo1*1000, zredukowana do  70  kolumn, Cross-Vall score: 0.5182795698924731
# tablicaCalekPo1*1000, zredukowana do  80  kolumn, Cross-Vall score: 0.5275268817204302
# tablicaCalekPo1*1000, zredukowana do  90  kolumn, Cross-Vall score: 0.513763440860215
# tablicaCalekPo1*1000, zredukowana do  100  kolumn, Cross-Vall score: 0.5283870967741935

# %%
tablicaCalekPo1Znormalizowana = normalizuj(tablicaCalekPo1)

# %%
print("tablicaCalekPo1*1000, Cross-Vall score:", crossValidation(svm, (((tablicaCalekPo1Znormalizowana[indeksy]).T[:200]).T)*1000, zmiana, 5))
# Out:
# tablicaCalekPo1*1000, Cross-Vall score: 0.5036559139784946

# %%
print("tablicaCalekPo1*1000, Cross-Vall score:", crossValidation(svm, (((tablicaCalekPo1Znormalizowana[indeksy]).T[:40]).T), zmiana, 5))
# Out:
# tablicaCalekPo1*1000, Cross-Vall score: 0.5116129032258063

# %%
print("tablicaCalekPo1*1000, zredukowana do ", i, " kolumn, Cross-Vall score:", crossValidation(svm, (((tablicaCalekPo1BezDzielenia[indeksy]).T[:100]).T), zmiana, 5))

# %%
def wyliczCViWypisz(nazwa, tablica, mnoznik, liczbaKolumn, iloscIteracji):
    if mnoznik != 1:
        nazwa += '*' + str(mnoznik)
    wynik = crossValidation(svm, (((tablica[indeksy]).T[:liczbaKolumn]).T)*mnoznik, zmiana, iloscIteracji)
    print(nazwa, "zredukowana do ", liczbaKolumn, " kolumn, Cross-Vall score: ", wynik)

# %%
wyliczCViWypisz("tablicaCalekPo1", tablicaCalekPo1, 1000, 100, 10)
# Out:
# tablicaCalekPo1*1000 zredukowana do  100  kolumn, Cross-Vall score:  0.5283870967741935

# %%
wyliczCViWypisz("tablicaCalekPo1BezDzielenia", tablicaCalekPo1BezDzielenia, 1, 100, 10)
# Out:
# tablicaCalekPo1BezDzielenia zredukowana do  100  kolumn, Cross-Vall score:  0.5204301075268817

# %%
i = 80
wyliczCViWypisz("tablicaCalekPo1", tablicaCalekPo1, 1000, i, 10)
wyliczCViWypisz("tablicaCalekPo1BezDzielenia", tablicaCalekPo1BezDzielenia, 1, i, 10)
# Out:
# tablicaCalekPo1*1000 zredukowana do  80  kolumn, Cross-Vall score:  0.5316129032258063
# tablicaCalekPo1BezDzielenia zredukowana do  80  kolumn, Cross-Vall score:  0.5365591397849463

# %%
i = 90
wyliczCViWypisz("tablicaCalekPo1", tablicaCalekPo1, 1000, i, 10)
wyliczCViWypisz("tablicaCalekPo1BezDzielenia", tablicaCalekPo1BezDzielenia, 1, i, 10)
# Out:
# tablicaCalekPo1*1000 zredukowana do  90  kolumn, Cross-Vall score:  0.5251612903225806
# tablicaCalekPo1BezDzielenia zredukowana do  90  kolumn, Cross-Vall score:  0.5225806451612903

# %%
i = 100
wyliczCViWypisz("tablicaCalekPo1", tablicaCalekPo1, 1000, i, 10)
wyliczCViWypisz("tablicaCalekPo1BezDzielenia", tablicaCalekPo1BezDzielenia, 1, i, 10)
# Out:
# tablicaCalekPo1*1000 zredukowana do  100  kolumn, Cross-Vall score:  0.54
# tablicaCalekPo1BezDzielenia zredukowana do  100  kolumn, Cross-Vall score:  0.5273118279569892

# %%
i = 110
wyliczCViWypisz("tablicaCalekPo1", tablicaCalekPo1, 1000, i, 10)
wyliczCViWypisz("tablicaCalekPo1BezDzielenia", tablicaCalekPo1BezDzielenia, 1, i, 10)
# Out:
# tablicaCalekPo1*1000 zredukowana do  110  kolumn, Cross-Vall score:  0.5270967741935485
# tablicaCalekPo1BezDzielenia zredukowana do  110  kolumn, Cross-Vall score:  0.5249462365591397

# %%
i = 120
wyliczCViWypisz("tablicaCalekPo1", tablicaCalekPo1, 1000, i, 10)
wyliczCViWypisz("tablicaCalekPo1BezDzielenia", tablicaCalekPo1BezDzielenia, 1, i, 10)
# Out:
# tablicaCalekPo1*1000 zredukowana do  120  kolumn, Cross-Vall score:  0.5283870967741935
# tablicaCalekPo1BezDzielenia zredukowana do  120  kolumn, Cross-Vall score:  0.5197849462365591

# %%
i = 130
wyliczCViWypisz("tablicaCalekPo1", tablicaCalekPo1, 1000, i, 10)
wyliczCViWypisz("tablicaCalekPo1BezDzielenia", tablicaCalekPo1BezDzielenia, 1, i, 10)
# Out:
# tablicaCalekPo1*1000 zredukowana do  130  kolumn, Cross-Vall score:  0.5294623655913978
# tablicaCalekPo1BezDzielenia zredukowana do  130  kolumn, Cross-Vall score:  0.5298924731182796

# %%
i = 140
wyliczCViWypisz("tablicaCalekPo1", tablicaCalekPo1, 1000, i, 10)
wyliczCViWypisz("tablicaCalekPo1BezDzielenia", tablicaCalekPo1BezDzielenia, 1, i, 10)
# Out:
# tablicaCalekPo1*1000 zredukowana do  140  kolumn, Cross-Vall score:  0.5195698924731182
# tablicaCalekPo1BezDzielenia zredukowana do  140  kolumn, Cross-Vall score:  0.5277419354838708

# %%
i = 150
wyliczCViWypisz("tablicaCalekPo1", tablicaCalekPo1, 1000, i, 10)
wyliczCViWypisz("tablicaCalekPo1BezDzielenia", tablicaCalekPo1BezDzielenia, 1, i, 10)
# Out:
# tablicaCalekPo1*1000 zredukowana do  150  kolumn, Cross-Vall score:  0.5238709677419354
# tablicaCalekPo1BezDzielenia zredukowana do  150  kolumn, Cross-Vall score:  0.5204301075268817

# %%
i = 160
wyliczCViWypisz("tablicaCalekPo1", tablicaCalekPo1, 1000, i, 10)
wyliczCViWypisz("tablicaCalekPo1BezDzielenia", tablicaCalekPo1BezDzielenia, 1, i, 10)
# Out:
# tablicaCalekPo1*1000 zredukowana do  160  kolumn, Cross-Vall score:  0.5324731182795698
# tablicaCalekPo1BezDzielenia zredukowana do  160  kolumn, Cross-Vall score:  0.529032258064516

# %%
i = 170
wyliczCViWypisz("tablicaCalekPo1", tablicaCalekPo1, 1000, i, 10)
wyliczCViWypisz("tablicaCalekPo1BezDzielenia", tablicaCalekPo1BezDzielenia, 1, i, 10)
# Out:
# tablicaCalekPo1*1000 zredukowana do  170  kolumn, Cross-Vall score:  0.5260215053763441
# tablicaCalekPo1BezDzielenia zredukowana do  170  kolumn, Cross-Vall score:  0.5372043010752688

# %%
i = 180
wyliczCViWypisz("tablicaCalekPo1", tablicaCalekPo1, 1000, i, 10)
wyliczCViWypisz("tablicaCalekPo1BezDzielenia", tablicaCalekPo1BezDzielenia, 1, i, 10)
# Out:
# tablicaCalekPo1*1000 zredukowana do  180  kolumn, Cross-Vall score:  0.5326881720430108
# tablicaCalekPo1BezDzielenia zredukowana do  180  kolumn, Cross-Vall score:  0.5301075268817204

# %%
i = 190
wyliczCViWypisz("tablicaCalekPo1", tablicaCalekPo1, 1000, i, 10)
wyliczCViWypisz("tablicaCalekPo1BezDzielenia", tablicaCalekPo1BezDzielenia, 1, i, 10)
# Out:
# tablicaCalekPo1*1000 zredukowana do  190  kolumn, Cross-Vall score:  0.5268817204301075
# tablicaCalekPo1BezDzielenia zredukowana do  190  kolumn, Cross-Vall score:  0.5331182795698924

# %%
i = 200
wyliczCViWypisz("tablicaCalekPo1", tablicaCalekPo1, 1000, i, 10)
wyliczCViWypisz("tablicaCalekPo1BezDzielenia", tablicaCalekPo1BezDzielenia, 1, i, 10)
# Out:
# tablicaCalekPo1*1000 zredukowana do  200  kolumn, Cross-Vall score:  0.5260215053763441
# tablicaCalekPo1BezDzielenia zredukowana do  200  kolumn, Cross-Vall score:  0.5305376344086021

# %%
i = 80
wyliczCViWypisz("tablicaCalekPo1BezDzielenia", normalizuj(tablicaCalekPo1BezDzielenia), 1, i, 10)
wyliczCViWypisz("tablicaCalekPo1BezDzielenia", normalizuj(tablicaCalekPo1BezDzielenia.T).T, 1, i, 10)
# Out:
# tablicaCalekPo1BezDzielenia zredukowana do  80  kolumn, Cross-Vall score:  0.5131182795698925
# tablicaCalekPo1BezDzielenia zredukowana do  80  kolumn, Cross-Vall score:  0.5337634408602151

# %%
i = 80
wyliczCViWypisz("tablicaCalekRosnaca", tablicaCalekRosnaca, 1, i, 10)
wyliczCViWypisz("tablicaCalekRosnaca", tablicaCalekRosnaca, 1000, i, 10)
wyliczCViWypisz("tablicaTickowRosnaca", tablicaTickowRosnaca, 1, i, 10)
# Out:
# tablicaCalekRosnaca zredukowana do  80  kolumn, Cross-Vall score:  0.5017204301075269
# tablicaCalekRosnaca*1000 zredukowana do  80  kolumn, Cross-Vall score:  0.5292473118279569
# tablicaTickowRosnaca zredukowana do  80  kolumn, Cross-Vall score:  0.5010752688172043

# %%
i = 80
wyliczCViWypisz("tablicaCalekRosnacaBezDzielenia", tablicaCalekRosnacaBezDzielenia, 1, i, 10)
# Out:
# tablicaCalekRosnacaBezDzielenia zredukowana do  80  kolumn, Cross-Vall score:  0.5187096774193549

# %%
for i in range(10, 250, 5):
    k = 20
    wyliczCViWypisz("tablicaCalekPo1", tablicaCalekPo1, 1000, i, k)
    wyliczCViWypisz("tablicaCalekPo1BezDzielenia", tablicaCalekPo1BezDzielenia, 1, i, k)
    wyliczCViWypisz("tablicaCalekRosnaca", tablicaCalekRosnaca, 1000, i, k)
    wyliczCViWypisz("tablicaCalekRosnacaBezDzielenia", tablicaCalekRosnacaBezDzielenia, 1, i, k)
    print()

# %%
tablicaCalekPo1BezDzielenia
# Out:
# array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  9.90453803e+00,   1.06526835e+01,   8.94163321e+00, ...,
#           3.03548104e-42,   9.31914230e-01,   1.89561250e-42],
#        ...,
#        [  5.27539950e+01,   5.27108165e+01,   5.25109527e+01, ...,
#           1.36751789e-45,   6.42112192e-46,   4.63149595e-46],
#        [  5.39386653e+01,   5.38927707e+01,   5.36766993e+01, ...,
#           5.23943095e-48,   2.35550199e-48,   1.67717410e-48],
#        [  5.40494258e+01,   5.40085438e+01,   5.37805248e+01, ...,
#           3.30933818e-48,   1.42589812e-48,   1.05431180e-48]])

# %%
wyliczCViWypisz("tablicaCalekPo1BezDzielenia", tablicaCalekPo1BezDzielenia, 1, 170, 5)
# Out:
# tablicaCalekPo1BezDzielenia zredukowana do  170  kolumn, Cross-Vall score:  0.5243010752688172

# %%
tabCalPo1razy170 = (((tablicaCalekPo1BezDzielenia[indeksy]).T[:170]).T)*1

# %%
KMeans

# %%
tabCalPo1razy170.shape[0]
# Out:
# 4652

# %%
kmeans9 = KMeans(init='k-means++', n_clusters=10, n_init=3, n_jobs = -2)

# %%
kmeans9.fit(tabCalPo1razy170)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=10, n_init=3, n_jobs=-2, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmeans9.

# %%
def crossValidationGrouping(clf, data, dataClass, k, kmeans):
    size = data.shape[0]
    arr = np.arange(size)
    np.random.shuffle(arr)
    err = 0
    n = int(size / k)
    for i in range(k):
        testMask = arr[np.arange(i*n,min((i+1)*n,size))]
        trainMask = arr[np.concatenate((np.arange(i*n),np.arange((i+1)*n,size)))]
        xTrain = data[trainMask]
        yTrain = dataClass[trainMask]
        xTest = data[testMask]
        yTest = dataClass[testMask]  
#         clf = clf.fit(X_train, y_train)
#         if isinstance(clf, GridSearchCV):
#             clf = clf.best_estimator_
#         y_train = y_train.reshape((y_train.shape[0], 1))
#         poczym = clf.decision_function(X_train).reshape(y_train.shape)
#         y_train1 = y_train > 0;
#         nana = kiedy(X_train, y_train1, poczym)        
#         err += testujDecisionFunction(X_test, y_test, nana, clf)
        err += przelicz(xTrain, xTest, yTrain, yTest, kmeans, clf)
    return float(err) / k

# %%
def przelicz(xTrain, xTest, yTrain, yTest, kmeans, clf):
    kmeans.fit(xTrain)
    trainLabels = kmeans.labels_
    testLabels = kmeans.predict(xTest)
    k = np.max([np.max(trainLabels), np.max(testLabels)])
    n = xTrain.shape[0]
    err = 0
    for i in range(k):
        err += licz(xTrain[trainLabels==k], xTest[testLabels==k], yTrain[trainLabels==k], yTest[testLabels==k], clf)
    return (err / k)

# %%
def licz(xTrain, xTest, yTrain, yTest, clf):
    clf = clf.fit(xTrain, yTrain)
    if isinstance(clf, GridSearchCV):
        clf = clf.best_estimator_
    yTrain = yTrain.reshape((yTrain.shape[0], 1))
    poczym = clf.decision_function(xTrain).reshape(yTrain.shape)
    yTrain1 = yTrain > 0;
    nana = kiedy(xTrain, yTrain1, poczym)  
    return testujDecisionFunction(xTest, yTest, nana, clf)

# %%
def wyliczCViWypiszGrouping(nazwa, tablica, mnoznik, liczbaKolumn, iloscIteracji, kmeans, ilerazy):
    if mnoznik != 1:
        nazwa += '*' + str(mnoznik)
    wynik = 0
    for i in range(ilerazy):
        wynik += crossValidationGrouping(svm, (((tablica[indeksy]).T[:liczbaKolumn]).T)*mnoznik, zmiana, iloscIteracji, kmeans)
    wynik = wynik / ilerazy
    print(nazwa, "zredukowana do ", liczbaKolumn, " kolumn, Cross-Vall score: ", wynik)

# %%
kmeans = KMeans(init='k-means++', n_clusters=5, n_init=3, n_jobs = -2)
wyliczCViWypiszGrouping("tablicaCalekPo1BezDzielenia", tablicaCalekPo1BezDzielenia, 1, 170, 2, kmeans)
# Out:
# (2326,) (2326,)
# (2326,) (2326,)
# tablicaCalekPo1BezDzielenia zredukowana do  170  kolumn, Cross-Vall score:  0.5425806451612903

# %%
kmeans = KMeans(init='k-means++', n_clusters=5, n_init=3, n_jobs = -2)
wyliczCViWypiszGrouping("tablicaCalekPo1BezDzielenia", tablicaCalekPo1BezDzielenia, 1, 170, 5, kmeans)
# Out:
# (930,) (3722,)
# (930,) (3722,)
# (930,) (3722,)
# (930,) (3722,)
# (930,) (3722,)
# tablicaCalekPo1BezDzielenia zredukowana do  170  kolumn, Cross-Vall score:  0.5608040646923399

# %%
kmeans = KMeans(init='k-means++', n_clusters=8, n_init=3, n_jobs = -2)
wyliczCViWypiszGrouping("tablicaCalekPo1BezDzielenia", tablicaCalekPo1BezDzielenia, 1, 170, 5, kmeans)
# Out:
# (930,) (3722,)
# (930,) (3722,)
# (930,) (3722,)
# (930,) (3722,)
# (930,) (3722,)
# tablicaCalekPo1BezDzielenia zredukowana do  170  kolumn, Cross-Vall score:  0.5366023589512434

# %%
kmeans = KMeans(init='k-means++', n_clusters=4, n_init=3, n_jobs = -2)
wyliczCViWypiszGrouping("tablicaCalekPo1BezDzielenia", tablicaCalekPo1BezDzielenia, 1, 170, 5, kmeans)
# Out:
# (930,) (3722,)
# (930,) (3722,)
# (930,) (3722,)
# (930,) (3722,)
# (930,) (3722,)
# tablicaCalekPo1BezDzielenia zredukowana do  170  kolumn, Cross-Vall score:  0.5437682339599593

# %%
kmeans = KMeans(init='k-means++', n_clusters=4, n_init=3, n_jobs = -2)
wyliczCViWypiszGrouping("tablicaCalekPo1BezDzielenia", tablicaCalekPo1BezDzielenia, 1, 170, 10, kmeans)
# Out:
# (465,) (4187,)
# (465,) (4187,)
# (465,) (4187,)
# (465,) (4187,)
# (465,) (4187,)
# (465,) (4187,)
# (465,) (4187,)
# (465,) (4187,)
# (465,) (4187,)
# (465,) (4187,)
# tablicaCalekPo1BezDzielenia zredukowana do  170  kolumn, Cross-Vall score:  0.5453906003406261

# %%
kmeans = KMeans(init='k-means++', n_clusters=5, n_init=3, n_jobs = -2)
wyliczCViWypiszGrouping("tablicaCalekPo1BezDzielenia", tablicaCalekPo1BezDzielenia, 1, 170, 5, kmeans, 10)
# Out:
# tablicaCalekPo1BezDzielenia zredukowana do  170  kolumn, Cross-Vall score:  0.5310685954523438

# %%
# testowanuie kmeans

# %%
kmeans = KMeans(init='k-means++', n_clusters=5, n_init=3, n_jobs = -2)

# %%
def testujKMeans(kmeans, x, procent = 0.2, ileRazy = 1, nazwa="brak nazwy", kolej = None):
    kmeans.tol = np.max(x) / 1000
    wynik = 0
    size = x.shape[0]
    arr = np.arange(size)
    n = (int) (procent*size)
    for i in range(ileRazy):
        np.random.shuffle(arr)
        trainMask = arr[np.arange(n)]
        testMask = arr[np.arange(n,size)]
        trainData = x[trainMask]
        testData = x[testMask]
        kmeans.fit(trainData)
        wynik += kmeans.score(testData)
    wynik = wynik / ileRazy

    print("Wynik dla", nazwa, "clusters:", kolej ,", to: (/sum)", wynik / np.sum(x), ", (/sqrt(sum)):", wynik/np.sqrt(np.sum(x)))

# %%
czas = time.time()
kmeans = KMeans(init='k-means++', n_clusters=5, n_init=3, n_jobs = 8)
for k in slownik:    
    testujKMeans(kmeans, slownik[k], nazwa = k, procent = 0.5, ileRazy =2)
print (time.time()-czas)
# Out:
# Wynik dla tablicaCalekPo1 clusters: None , to: (/sum) -0.00226264856754 , (/sqrt(sum)): -0.167259853724
# Wynik dla tablicaCalekRosnacaBezDzielenia clusters: None , to: (/sum) -0.669419849252 , (/sqrt(sum)): -1148.17535964
# Wynik dla tablicaTickowPo1 clusters: None , to: (/sum) -243160.427586 , (/sqrt(sum)): -6965419592.32
# Wynik dla tablica clusters: None , to: (/sum) -148874.944303 , (/sqrt(sum)): -4355054853.05
# Wynik dla tablicaTickowRosnaca clusters: None , to: (/sum) -330995.554006 , (/sqrt(sum)): -3347622608.83
# Wynik dla tabCalPo1razy170 clusters: None , to: (/sum) -4.36312357914 , (/sqrt(sum)): -13192.2540393
# Wynik dla tablicaCalekPo1BezDzielenia clusters: None , to: (/sum) -4.50706726712 , (/sqrt(sum)): -14907.3581011
# 14.803152084350586

# %%
for k in slownik:    
    for i in range(2, 20):
        kmeans = KMeans(init='k-means++', n_clusters=i, n_init=2, n_jobs = 8)
        testujKMeans(kmeans, slownik[k], nazwa = k, procent = 0.5, ileRazy = 2, kolej = i)
# Out:
# Wynik dla tablicaCalekPo1 clusters: 2 , to: (/sum) -0.00266510230364 , (/sqrt(sum)): -0.197010100402
# Wynik dla tablicaCalekPo1 clusters: 3 , to: (/sum) -0.00252498216684 , (/sqrt(sum)): -0.186652118203
# Wynik dla tablicaCalekPo1 clusters: 4 , to: (/sum) -0.00236896605068 , (/sqrt(sum)): -0.175119070985
# Wynik dla tablicaCalekPo1 clusters: 5 , to: (/sum) -0.00227323231106 , (/sqrt(sum)): -0.168042226832
# Wynik dla tablicaCalekPo1 clusters: 6 , to: (/sum) -0.00214332845438 , (/sqrt(sum)): -0.158439454056
# Wynik dla tablicaCalekPo1 clusters: 7 , to: (/sum) -0.00207318378881 , (/sqrt(sum)): -0.153254209352
# Wynik dla tablicaCalekPo1 clusters: 8 , to: (/sum) -0.00198665676912 , (/sqrt(sum)): -0.146857945759
# Wynik dla tablicaCalekPo1 clusters: 9 , to: (/sum) -0.00178279295351 , (/sqrt(sum)): -0.131787893578
# Wynik dla tablicaCalekPo1 clusters: 10 , to: (/sum) -0.00172770568214 , (/sqrt(sum)): -0.127715723872
# ...

# %%
np.max(tablicaCalekPo1 )
# Out:
# 0.20856592777014171

# %%
gammas = [1e-5, 1e-2, 1, 1e2, 1e5]
kernels = ['linear', 'rbf']
Cs = [1e-5, 1e-2, 1, 1e2, 1e5]
tols = [1e-5, 1e-2, 1, 1e2, 1e5]

procent = 0.7
print("procent =", procent)
print('Czyste  S     N     S->N    N->S')
for gamma in gammas:
    for C in Cs:
        for tol in tols:
            for kernel in kernels:
                svm = SVC(class_weight='balanced', gamma = gamma, kernel = kernel, C = C, tol = tol)
                wynik1, wynik2, wynik3, wynik4, wynik5 = test("imbalance", tab, tabS, tabN, tabSN, tabNS, svm, indeksyDni, procent = procent)
                odpowiedz = "{0:0.4f}  {1:0.4f}  {2:0.4f}  {3:0.4f}  {4:0.4f}".format(wynik1, wynik2, wynik3, wynik4, wynik5)
                if (wynik1 > 0.52 or wynik2 > 0.52 or wynik3 > 0.52 or wynik4 > 0.52 or wynik5 > 0.52):
                    odpowiedz = "\x1b[31m\"{0:0.4f}  {1:0.4f}  {2:0.4f}  {3:0.4f}  {4:0.4f}\"\x1b[0m".format(wynik1, wynik2, wynik3, wynik4, wynik5)
                
                print(odpowiedz, "- dla: g:", gamma, "k:", kernel, "C:", C, "tol:", tol)
# Out:
# procent = 0.7
# Czyste  S     N     S->N    N->S
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-de6a52e5f69f> in <module>()
#      11         for tol in tols:
#      12             for kernel in kernels:
# ---> 13                 svm = SVC(class_weight='balanced', gamma = gamma, kernel = kernel, C = C, tol = tol)
#      14                 wynik1, wynik2, wynik3, wynik4, wynik5 = test("imbalance", tab, tabS, tabN, tabSN, tabNS, svm, indeksyDni, procent = procent)
#      15                 odpowiedz = "{0:0.4f}  {1:0.4f}  {2:0.4f}  {3:0.4f}  {4:0.4f}".format(wynik1, wynik2, wynik3, wynik4, wynik5)
#
# NameError: name 'SVC' is not defined
